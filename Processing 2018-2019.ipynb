# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("season-1819_csv.csv")

# %%
df.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# ...

# %%
sum_column = df["FTHG"] + df["FTAG"]
df["Total goals scored in the match"] = sum_column

# %%
sum_column = df["HS"] + df["AS"]
df["Total shots in the match"] = sum_column

# %%
new_dataset = df.loc[:, ['Div','Date','HomeTeam','AwayTeam','FTHG','FTAG','Total goals scored in the match','FTR','HTHG','HTAG','HTR','Referee','HS','AS','Total shots in the match','HST','AST']]

# %%
new_dataset.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2
#
#    Total goals scored in the match FTR  HTHG  HTAG HTR     Referee  HS  AS  \
# 0                                3   H     1     0   H  A Marriner   8  13
# 1                                2   H     1     0   H    K Friend  12  10
# 2                                2   A     0     1   A      M Dean  15  10
# 3                                3   A     0     2   A  C Kavanagh   6  13
# 4                                3   A     1     2   A  M Atkinson  15  15
#
#    Total shots in the match  HST  AST
# 0                        21    6    4
# 1                        22    4    1
# ...

# %%
new_dataset.tail()
# Out:
#     Div        Date     HomeTeam      AwayTeam  FTHG  FTAG  \
# 375  E0  12/05/2019    Liverpool        Wolves     2     0
# 376  E0  12/05/2019   Man United       Cardiff     0     2
# 377  E0  12/05/2019  Southampton  Huddersfield     1     1
# 378  E0  12/05/2019    Tottenham       Everton     2     2
# 379  E0  12/05/2019      Watford      West Ham     1     4
#
#      Total goals scored in the match FTR  HTHG  HTAG HTR     Referee  HS  AS  \
# 375                                2   H     1     0   H  M Atkinson  13   7
# 376                                2   A     0     1   A      J Moss  26  13
# 377                                2   D     1     0   H   L Probert  10  10
# 378                                4   D     1     0   H  A Marriner  11  17
# 379                                5   A     0     2   A  C Kavanagh  17  16
#
#      Total shots in the match  HST  AST
# 375                        20    5    2
# 376                        39   10    4
# ...

# %%
plt.plot(df['FTHG'],'o',color='blue')
plt.xlabel('Match Number')
plt.ylabel('Home Team Goals Scored in a match')
# Out:
# Text(0, 0.5, 'Home Team Goals Scored in a match')

# %%
plt.plot(df['FTAG'],'o',color='red')
plt.xlabel('Match Number')
plt.ylabel('Away Team Goals Scored in a match')
# Out:
# Text(0, 0.5, 'Away Team Goals Scored in a match')

# %%
plt.plot(df['HS'],'o',color='blue')
plt.xlabel('Match Number')
plt.ylabel('Home Team Shots Takenn in a match')
# Out:
# Text(0, 0.5, 'Home Team Shots Takenn in a match')

# %%
plt.plot(df['AS'],'o',color='red')
plt.xlabel('Match Number')
plt.ylabel('Away Team shots taken in a match')
# Out:
# Text(0, 0.5, 'Away Team shots taken in a match')

# %%
plt.plot(df['FTHG'],'o',color='blue')
plt.plot(df['FTAG'],'o',color='red')
plt.xlabel('Match Number')
plt.ylabel('Home team Goals Scored vs Away team Goals Scored in a match')
# Out:
# Text(0, 0.5, 'Home team Goals Scored vs Away team Goals Scored in a match')

# %%
plt.plot(df['HS'],'o',color='blue')
plt.plot(df['AS'],'o',color='red')
plt.plot(df['FTHG'],'o',color='blue')
plt.plot(df['FTAG'],'o',color='red')
plt.xlabel('Match Number')
plt.ylabel('Home team Shots Taken vs Away team Shots Taken in a match')
# Out:
# Text(0, 0.5, 'Home team Shots Taken vs Away team Shots Taken in a match')

# %%
new_dataset['HS'].corr(new_dataset['FTHG'])
# Out:
# 0.3322583985596536

# %%
new_dataset['AS'].corr(new_dataset['FTAG'])
# Out:
# 0.2907178647590212

# %%
plt.figure()
plt.plot(df['FTHG'],'o',color ='Lime')
plt.plot(df['HS'],'o',color ='blue')
plt.xlabel('Match Number')
plt.ylabel('Home team Goals scored vs Home team shots taken')
# Out:
# Text(0, 0.5, 'Home team Goals scored vs Home team shots taken')

# %%
plt.figure()
plt.plot(df['FTAG'],'o',color ='orange')
plt.plot(df['AS'],'o',color ='red')
plt.xlabel('Match Number')
plt.ylabel('Away team Goals scored vs Away team shots taken')
# Out:
# Text(0, 0.5, 'Away team Goals scored vs Away team shots taken')

# %%
plt.figure()
plt.plot(df['Total goals scored in the match'],'o',color ='orange')
plt.plot(df['Total shots in the match'],'o',color ='red')
plt.xlabel('Match Number')
plt.ylabel('Total goals scored in the match vs Total shots in the match')
# Out:
# Text(0, 0.5, 'Total goals scored in the match vs Total shots in the match')

# %%
new_dataset['Total goals scored in the match'].corr(new_dataset['Total shots in the match'])
# Out:
# 0.2250900189526669
